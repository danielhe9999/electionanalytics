# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
covid = pd.read_csv('CovidDeaths.csv')
population = pd.read_csv('PopulationFinal.csv')
poverty = pd.read_csv('PovertyFinal.csv')
education = pd.read_csv('EducationFinal.csv')
electionresults = pd.read_csv('ElectionResults.csv')

# %%
covid = covid.drop(['Unnamed: 0'], axis = 1)
covid = covid.set_index('County + State')

# %%
electionresults = electionresults.set_index('County + State')

# %%
population = population.drop(['Unnamed: 0'], axis = 1)
population = population.set_index('County + State')

# %%
poverty = poverty.drop(['Unnamed: 0'], axis = 1)
poverty = poverty.set_index('County + State')

# %%
education = education.drop(['Unnamed: 0'], axis = 1)
education = education.set_index('County + State')

# %%
len(poverty)
# Out:
# 3113

# %%
len(education)
# Out:
# 3118

# %%
len(electionresults)
# Out:
# 4232

# %%
len(population)
# Out:
# 3114

# %%
len(covid)
# Out:
# 3112

# %%
electionresults = electionresults.join(education, lsuffix='_caller', rsuffix='_other')

# %%
electionresults = electionresults.join(population, lsuffix='_caller', rsuffix='_other')

# %%
electionresults = electionresults.join(poverty, lsuffix='_caller', rsuffix='_other')

# %%
electionresults = electionresults.join(covid, lsuffix='_caller', rsuffix='_other')

# %%
len(electionresults)
# Out:
# 4300

# %%
electionresults
# Out:
#                Total number of voters   Winner  Margin of victory  \
# County + State
# Abbeville,SC                   14,552   Trump                29.0
# Abbot,ME                          417   Trump                40.0
# Abington,MA                     9,550   Biden                10.0
# Acadia,LA                      28,425   Trump                60.0
# Accomack,VA                    23,603   Trump                28.0
# ...                               ...      ...                ...
# Yuma,AZ                        59,895   Trump                 8.0
# Yuma,CO                         4,885   Trump                67.0
# Zapata,TX                       3,867   Trump                 5.0
# Zavala,TX                       4,379   Biden                31.0
# Ziebach,SD                        906   Biden                 8.0
#
#                 Percent of adults with less than a high school diploma, 2000  \
# County + State
# ...

# %%
df = electionresults

# %%
df
# Out:
#                Total number of voters   Winner  Margin of victory  \
# County + State
# Abbeville,SC                   14,552   Trump                29.0
# Abbot,ME                          417   Trump                40.0
# Abington,MA                     9,550   Biden                10.0
# Acadia,LA                      28,425   Trump                60.0
# Accomack,VA                    23,603   Trump                28.0
# ...                               ...      ...                ...
# Yuma,AZ                        59,895   Trump                 8.0
# Yuma,CO                         4,885   Trump                67.0
# Zapata,TX                       3,867   Trump                 5.0
# Zavala,TX                       4,379   Biden                31.0
# Ziebach,SD                        906   Biden                 8.0
#
#                 Percent of adults with less than a high school diploma, 2000  \
# County + State
# ...

# %%
df_final = df.dropna()

# %%
df_final
# Out:
#                Total number of voters   Winner  Margin of victory  \
# County + State
# Abbeville,SC                   14,552   Trump                29.0
# Acadia,LA                      28,425   Trump                60.0
# Accomack,VA                    23,603   Trump                28.0
# Ada,ID                        259,389   Trump                 4.0
# Adair,IA                        4,183   Trump                41.0
# ...                               ...      ...                ...
# Yuma,AZ                        59,895   Trump                 8.0
# Yuma,CO                         4,885   Trump                67.0
# Zapata,TX                       3,867   Trump                 5.0
# Zavala,TX                       4,379   Biden                31.0
# Ziebach,SD                        906   Biden                 8.0
#
#                 Percent of adults with less than a high school diploma, 2000  \
# County + State
# ...

# %%
df_final.to_csv('ElectionFinalResults.csv')
